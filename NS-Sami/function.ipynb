# %%
print("Hello")
print("World!")

print("Hello", end="  " )
print("World!")

print("cat", 'dog', 'mice',sep=",/")
# Out:
# Hello
# World!
# Hello  World!
# cat,/dog,/mice

# %%
# page -70
def spam():
     eggs = "spam_eggs"
eggs = 'global_eggs'
spam()
print(eggs)

def spam():
    global eggs
    eggs = "spam_eggs"
eggs = 'global_eggs'
spam()
print(eggs)
# Out:
# global_eggs
# spam_eggs

# %%
def spam():
    print(eggs)

eggs = 42
spam()
# Out:
# 42
